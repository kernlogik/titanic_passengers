# %%
import pandas as pd

df = pd.read_parquet("titanic.parquet")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

sns.set_theme()

bins = [1,15,25,65,80]
category_names = ["Kinder", "Jugendliche", "Erwachsene", "Senioren"]
df["Age_Group"] = pd.cut(df["Age"], bins=bins, labels=category_names)

heatmap_data = df.pivot_table(
    index="Age_Group",
    columns="Sex",
    values="Survived",
    aggfunc="count"
)

ax = sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="Greens")
ax.invert_yaxis()

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64
