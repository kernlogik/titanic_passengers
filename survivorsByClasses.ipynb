# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import PercentFormatter

df = pd.read_parquet("titanic.parquet")



ax = sns.barplot(
    x = "Pclass",
    y = "Survived",
    data = df,
    hue = "Sex",
    palette = sns.color_palette("Set3"),
)

ax.set(xlabel="Passenger Class", ylabel="Survivors")

ax.yaxis.set_major_formatter(PercentFormatter(xmax=1))
# Out:
# /var/folders/gw/5m7j6_qj0dlcqvzjgmkzrh8r0000gn/T/ipykernel_10196/612528895.py:10: UserWarning: The palette list has more values (12) than needed (2), which may not be intended.
#   ax = sns.barplot(
